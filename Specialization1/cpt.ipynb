# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import scipy.ndimage  as nd
# %matplotlib inline

# %% [markdown]
# # Бета распределение $X \sim B(\alpha,\beta)$
# Математическое ожидание бета-распределения $EX = \frac{\alpha}{(\beta+\alpha)}$
#
# Дисперсия бета-распределения $DX = \frac{\alpha\beta}{(\alpha+\beta)^2(\alpha+\beta +1)}$

# %%
#  Задайте а (параметр альфа) и b (параметр бета)  больше нуля.
#
a = 0.5
b = 0.5
rv = sts.beta(a,b)

sample = rv.rvs(1000)

# %% [markdown]
# Гистограмма выборки и теоретическая плотность распределения

# %%
plt.hist(sample, normed=True, label ='hist pdf')

x = np.linspace(0,1,100)
pdf = rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf', lw = 2)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %% [markdown]
# # Эксперимент n = 5

# %%
N = 1000 # сгенерируем N выборок 
n = 5 # длина каждой выборки n

# %% [markdown]
# ## Подготовим нормально распределенную случайную величину
#
#  которая, согласно центральной предельной теореме, приближает распределение выборочных средних для исследуемой случайной величены, заданной бета-распределением
# Для вычисление матожидания используем формулу для матожидания бета-распределения  $EX = \frac{\alpha}{(\beta+\alpha)}$
# Для вычисления дисперсии используем формулу для дисперсии бета-распределения, деенного на количество элементов  в
# выборках, для которых мы считаем выборочное среднее $DX = \frac{\alpha\beta}{(\alpha+\beta)^2(\alpha+\beta +1)*n}$
# В качестве параметра scale нормального распределения используем $\sigma = \sqrt(DX)$
#
# Данные выкладки аналогичны для всех экспериментов

# %%
mu = a/(b+a) # матожидание совпадает с матожиданием исходной случайной величины rv
var = a*b /((a+b)*(a+b)*(a+b+1)) # посчитаем дисперсию исходной случайной величины rv
sigma = np.sqrt(var/n) # посчитаем среднеквадратичное отклонение для нормально распределенной случайной величины, 
#описывающей распределение выборочных средних 

# зададим нормально распределенную случайную величину
norm_rv = sts.norm(loc=mu, scale=sigma)

# %%
mu, var,sigma
# Out:
# (0.5, 0.125, 0.15811388300841897)

# %%
rv_avereges = np.array([])
for i in range(N):
    sample = rv.rvs(n)
    rv_avereges = np.append(rv_avereges,nd.mean(sample))

# %%
plt.hist(rv_avereges, normed=True, label ='hist len %d ' % n)
plt.ylabel('Number')
plt.xlabel('$x$')

x = np.linspace(0,1,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf', lw = 2)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %% [markdown]
# # Эксперимент n = 10

# %%
N = 1000 # сгенерируем N выборок 
n = 10 # длина каждой выборки n

# %% [markdown]
# ## Подготовим нормально распределенную случайную величину
#
#  которая, согласно центральной предельной теореме, приближает распределение выборочных средних для исследуемой случайной величены, заданной бета-распределением

# %%
mu = a/(b+a) # матожидание совпадает с матожиданием исходной случайной величины rv
var = a*b /((a+b)*(a+b)*(a+b+1)) # посчитаем дисперсию исходной случайной величины rv
sigma = np.sqrt(var/n) # посчитаем среднеквадратичное отклонение для нормально распределенной случайной величины, 
#описывающей распределение выборочных средних 
# зададим нормально распределенную случайную величину
norm_rv = sts.norm(loc=mu, scale=sigma)

# %%
mu, var,sigma
# Out:
# (0.5, 0.125, 0.11180339887498948)

# %%
rv_avereges = np.array([])
for i in range(N):
    sample = rv.rvs(n)
    rv_avereges = np.append(rv_avereges,nd.mean(sample))

# %%
plt.hist(rv_avereges, normed=True, label ='hist len %d ' % n)
plt.ylabel('Number')
plt.xlabel('$x$')

x = np.linspace(0,1,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf', lw = 2)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %% [markdown]
# # Эксперимент n = 50

# %%
N = 1000 # сгенерируем N выборок 
n = 50 # длина каждой выборки n

# %% [markdown]
# ## Подготовим нормально распределенную случайную величину
#
#  которая, согласно центральной предельной теореме, приближает распределение выборочных средних для исследуемой случайной величены, заданной бета-распределением

# %%
mu = a/(b+a) # матожидание совпадает с матожиданием исходной случайной величины rv
var = a*b /((a+b)*(a+b)*(a+b+1)) # посчитаем дисперсию исходной случайной величины rv
sigma = np.sqrt(var/n) # посчитаем среднеквадратичное отклонение для нормально распределенной случайной величины, 
#описывающей распределение выборочных средних 

# зададим нормально распределенную случайную величину
norm_rv = sts.norm(loc=mu, scale=sigma)

# %%
mu, var,sigma
# Out:
# (0.5, 0.125, 0.050000000000000003)

# %%
rv_avereges = np.array([])
for i in range(N):
    sample = rv.rvs(n)
    rv_avereges = np.append(rv_avereges,nd.mean(sample))

# %%
plt.hist(rv_avereges, normed=True, label ='hist len %d' % n)
plt.ylabel('Number')
plt.xlabel('$x$')

x = np.linspace(0,1,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='theoretical pdf', lw = 2)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %% [markdown]
# # Выводы

# %% [markdown]
# Наблюдая за графиками гистограмм плотности распределения выборочного среднего
# и графиками теоретической плотности рапределения нормальной случайной величены, которая, согласно центральной
# предельной теореме, описывает плотность распределения выборочного среднего, можно сделать вывод, что с ростом количества
# элементов выборок n точность аппроксимации увеличивается.
#
# Также видно, что дисперсия нормального распределения, описывющего случайную величину выборочных средних уменьшается с ростом n, что и понятно из ЦПТ, где $X_avrg \sim N(MX,\frac{DX}{n})$

# %% [markdown]
# Для исследования использовалась плотность бета-распределения, у которого есть два параметра альфа и бета,
# которые должны быть больше нуля.
# Написанный код позволяет менять значения этих параметров при выполнении скрипта.
# Форма графиков бета- распределения при разных значениях параметров очень отличается.
# Однако, как показали проведенный экспериметы, центральная предельная теорема работает
# для любых допустимых параметрах альфа и бета выбранного распределения.
